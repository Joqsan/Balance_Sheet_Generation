# %%
import camelot

# %%
# PDF file to extract tables from
file = "foo.pdf"

# %%
tables = camelot.read_pdf(file)

# %%
# number of tables extracted
print("Total tables extracted:", tables.n)
# Out:
# Total tables extracted: 1

# %%
# print the first table as Pandas DataFrame
print(tables[0].df)
# Out:
#               0            1                2                     3  \
# 0  Cycle \nName  KI \n(1/km)  Distance \n(mi)  Percent Fuel Savings
# 1                                                  Improved \nSpeed
# 2        2012_2         3.30              1.3                  5.9%
# 3        2145_1         0.68             11.2                  2.4%
# 4        4234_1         0.59             58.7                  8.5%
# 5        2032_2         0.17             57.8                 21.7%
# 6        4171_1         0.07            173.9                 58.1%
#
#                    4                  5                 6
# 0
# 1  Decreased \nAccel  Eliminate \nStops  Decreased \nIdle
# 2               9.5%              29.2%             17.4%
# 3               0.1%               9.5%              2.7%
# 4               1.3%               8.5%              3.3%
# 5               0.3%               2.7%              1.2%
# 6               1.6%               2.1%              0.5%

# %%
tables[0].df
# Out:
#               0            1                2                     3  \
# 0  Cycle \nName  KI \n(1/km)  Distance \n(mi)  Percent Fuel Savings
# 1                                                  Improved \nSpeed
# 2        2012_2         3.30              1.3                  5.9%
# 3        2145_1         0.68             11.2                  2.4%
# 4        4234_1         0.59             58.7                  8.5%
# 5        2032_2         0.17             57.8                 21.7%
# 6        4171_1         0.07            173.9                 58.1%
#
#                    4                  5                 6
# 0
# 1  Decreased \nAccel  Eliminate \nStops  Decreased \nIdle
# 2               9.5%              29.2%             17.4%
# 3               0.1%               9.5%              2.7%
# 4               1.3%               8.5%              3.3%
# 5               0.3%               2.7%              1.2%
# 6               1.6%               2.1%              0.5%

# %%
tables
# Out:
# <TableList n=1>

# %%
tables[0]
# Out:
# <Table shape=(7, 7)>

# %%
tables[0].parsing_report
# Out:
# {'accuracy': 99.02, 'whitespace': 12.24, 'order': 1, 'page': 1}

# %%
# %matplotlib inline
import matplotlib
# %matplotlib notebook

# %%
camelot.plot(tables[0], kind='text').show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
camelot.plot(tables[0], kind='grid').show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
camelot.plot(tables[0], kind='contour').show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
camelot.plot(tables[0], kind='line').show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
camelot.plot(tables[0], kind='joint').show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # table_areas

# %%
tables = camelot.read_pdf('table_areas.pdf', flavor='stream', table_areas=['316,499,566,337'])

# %%
tables[0].df
# Out:
#                                    0                1
# 0                                     One Withholding
# 1                     Payroll Period        Allowance
# 2                             Weekly         $\n71.15
# 3                           Biweekly           142.31
# 4                        Semimonthly           154.17
# 5                            Monthly           308.33
# 6                          Quarterly           925.00
# 7                       Semiannually         1,850.00
# 8                           Annually         3,700.00
# 9             Daily or Miscellaneous            14.23
# 10  (each day of the payroll period)

# %%
camelot.plot(tables[0], kind='grid').show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # table_regions

# %%
tables = camelot.read_pdf('table_regions.pdf', table_regions=['170,370,560,270'])

# %%
tables[0].df
# Out:
#                                              0                            1
# 0  Età dell’Assicurato \nall’epoca del decesso  Misura % di \nmaggiorazione
# 1                                        18-75                        1,00%
# 2                                        76-80                        0,50%
# 3                                    81 in poi                        0,10%

# %%
tables[0]._bbox
# Out:
# (178.34276935483868, 281.2699771949829, 479.581229032258, 358.7872149372862)

# %% [markdown]
# Checking:

# %%
tables2 = camelot.read_pdf('table_regions.pdf')

# %%
tables2.n
# Out:
# 1

# %%
tables2[0].df
# Out:
#                                                    0  \
# 0                                           FINALITÀ
# 1                             OPZIONI \nCONTRATTUALI
# 2                                             DURATA
# 3   LE COPERTURE ASSICURATIVE PER RISCHI DEMOGRAFICI
# 4                                         CASO MORTE
# 5
# 6
# 7
# 8
# 9
# 10                         ALTRI EVENTI \nASSICURATI
# 11                      ALTRE OPZIONI \nCONTRATTUALI
#
#                                                     1  \
# 0   Vittoria In Azione Italia PIR è un contratto d...
# 1                                       Non previste.
# 2   Il presente contratto è a vita intera, pertant...
# 3
# 4   In  caso  di  decesso  dell’Assicurato, \nla  ...
# 5
# 6
# 7
# 8
# 9   Si precisa che la Compagnia non offre alcuna g...
# 10                                      Non previsti.
# 11                                      Non previste.
#
#                                               2                            3  \
# 0
# 1
# 2
# 3
# 4
# 5   Età dell’Assicurato \nall’epoca del decesso  Misura % di \nmaggiorazione
# 6                                         18-75                        1,00%
# 7                                         76-80                        0,50%
# 8                                     81 in poi                        0,10%
# 9
# 10
# 11
#
#                           4
# 0
# 1
# 2
# 3
# 4   impegna  a  versare  ai
# 5
# 6
# 7
# 8
# 9
# 10
# 11

# %%
camelot.plot(tables[0], kind='text').show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# we found the approximate area. Let's retrieve the smaller table

# %% [raw]
# tables = camelot.read_pdf('table_regions.pdf', table_regions=['170,370,560,270'])

# %%
tables3 = camelot.read_pdf('table_regions.pdf', table_regions=['150, 375, 569, 270'])

# %%
tables3.n
# Out:
# 1

# %%
tables3[0].df
# Out:
#                                              0                            1
# 0  Età dell’Assicurato \nall’epoca del decesso  Misura % di \nmaggiorazione
# 1                                        18-75                        1,00%
# 2                                        76-80                        0,50%
# 3                                    81 in poi                        0,10%

# %% [markdown]
# # Specify column separators

# %%
tables = camelot.read_pdf('column_separators.pdf', flavor='stream', columns=['72,95,209,327,442,529,566,606,683'])

# %%
tables[0].df
# Out:
#                        0                                                  1  \
# 0                                                   FEBRUARY 2014 M27 (BUS)
# 1
# 2
# 3                LICENSE
# 4   NUMBER TYPE DBA NAME
# 5                                                                648765 AAA
# 6
# 7                                                                648766 AAA
# 8                                                                 82030 AAA
# 9                                                                509462 AAA
# 10
# 11                                                               509609 AAA
# 12
# 13                                                               402986 AAA
# 14
# 15                                                                79145 AAA
# 16                                                               600941 AAA
# 17
# 18                                                               478482 AAA
# 19                                                               505981 AAA
# 20                                                               429754 AAA
# 21
# 22                                                               429755 AAA
# 23                                                               415051 AAA
# 24                                                               106719 AAA
# 25
# 26                                                               625422 BAW
# 27
# 28                                                               464828 BAW
# 29
# 30                        184066 BAW AJANTA                             ...
# 31
# 32                                            547693 BAW AMERICINN OF SAYRE
# 33
# 34                                                               428377 BAW
# 35
# 36                                                               446957 BAW
# 37
# 38                                            632501 BAW BACK DOOR BARBECUE
# 39                        598515 BAW BAMBOO THAI BISTRO        BAMBOO TH...
# 40
# 41                                                               618693 BAW
# 42
# 43                        632575 BAW BASHU LEGENDS                 HYH H...
# 44
# 45                                                543149 BAW BEDLAM BAR-B-Q
#
#                         2                                                  3  \
# 0
# 1
# 2
# 3
# 4                                                              LICENSEE NAME
# 5                          ALLEGIANT AIR                    ALLEGIANT AIR...
# 6
# 7                          ALLEGIANT AIR                    ALLEGIANT AIR...
# 8                          AMERICAN AIRLINES           AMERICAN AIRLINES ...
# 9                          AMERICAN AIRLINES           AMERICAN AIRLINES ...
# 10                                                            AMERICAN EAGLE
# 11         AMERICAN EAGLE                                       AIRLINES INC
# 12                                                            AMERICAN EAGLE
# 13         AMERICAN EAGLE                                       AIRLINES INC
# 14
# 15                         DELTA AIR LINES                 DELTA AIR LINE...
# 16                         ENDEAVOR AIR                    ENDEAVOR AIR I...
# 17
# 18                          EXPRESSJET AIRLINES      EXPRESSJET AIRLINES INC
# 19                         SKYWEST AIRLINES            SKYWEST INC       ...
# 20                         SOUTHWEST AIRLINES       SOUTHWEST AIRLINES CO...
# 21    TULSA INTERNATIONAL
# 22                AIRPORT
# 23                         UNITED AIRLINES                UNITED AIRLINES...
# 24                         UNITED AIRLINES                UNITED AIRLINES...
# 25       A SENSU JAPANESE
# 26             RESTAURANT                               INFORMAL PARTNERSHIP
# 27       ADAMO'S ROUTE 66
# 28          ITALIAN VILLA                                           TADJ INC
# 29
# 30
# 31                                                             SAYRE LODGING
# 32                                                           ENTERPRISES LLC
# 33  ANDOLINI'S PIZZERIA &
# 34     ITALIAN RESTAURANT                                     ANDOLINI'S LLC
# 35         ASAHI JAPANESE
# 36             RESTAURANT
# 37                                                                SMOKEHOUSE
# 38                                                            ASSOCIATES INC
# 39
# 40          BANDANA RED'S
# 41             STEAKHOUSE
# 42
# 43
# 44                                                        DEEP FORK HOLDINGS
# 45                                                                       LLC
#
#                                                     4              5   6  \
# 0
# 1                                  OF ACTIVE LICENSES
# 2                            OKLAHOMA ABLE COMMISSION
# 3                                             PREMISE
# 4                                             ADDRESS           CITY  ST
# 5                                                                     OK
# 6                                    7777 EAST APACHE
# 7                                              STREET          TULSA  OK
# 8                                                                     OK
# 9                                                                     OK
# 10
# 11         7100 TERMINAL DRIVE          OKLAHOMA CITY                 OK
# 12
# 13                     7777 EAST APACHE DRIVE   TULSA                 OK
# 14                                WILL ROGERS AIRPORT
# 15                                          BOX 59975  OKLAHOMA CITY  OK
# 16                                                                    OK
# 17                                7100 TERMINAL DRIVE
# 18                                WILL ROGERS AIRPORT  OKLAHOMA CITY  OK
# 19                                                                    OK
# 20                                                                    OK
# 21
# 22  SOUTHWEST AIRLINES CO  7777 EAST APACHE DRIVE ...                 OK
# 23                                                                    OK
# 24                                                                    OK
# 25                               7123 SOUTH 92ND EAST
# 26                                     AVENUE SUITE J          TULSA  OK
# 27                                     2132 WEST GARY
# 28                                          BOULEVARD        CLINTON  OK
# 29                                        12215 NORTH
# 30                                       PENNSYLVANIA  OKLAHOMA CITY  OK
# 31
# 32                   2405 SOUTH EL CAMINO       SAYRE                 OK
# 33                             12140 EAST 96TH STREET
# 34                                         NORTH #106         OWASSO  OK
# 35
# 36  JIN CORPORATION                7831 EAST 71ST ...                 OK
# 37
# 38           315 NORTHWEST 23RD         OKLAHOMA CITY                 OK
# 39                                                                    OK
# 40
# 41  BRADSHAW, STEVE_LEN     37808 OLD HIGHWAY 270 ...                 OK
# 42                                  1522 WEST LINDSEY
# 43                                             STREET         NORMAN  OK
# 44
# 45         610 NORTHEAST 50TH           OKLAHOMA CITY                 OK
#
#         7               8           9
# 0
# 1                           3/19/2014
# 2
# 3
# 4     ZIP    PHONE NUMBER     EXPIRES
# 5   73159               -  2014/12/03
# 6
# 7   74115               -  2014/12/16
# 8   73159  (405) 680-3701  2014/09/14
# 9   74115  (918) 831-6302  2014/08/19
# 10
# 11  73159  (405) 680-3701  2014/08/19
# 12
# 13  74115  (859) 767-3747  2014/10/22
# 14
# 15  73159  (404) 773-9745  2014/05/11
# 16  73159  (901) 348-4100  2015/03/26
# 17
# 18  73159  (832) 353-1201  2014/05/08
# 19  73159  (405) 634-3000  2014/05/28
# 20  73159  (405) 682-4183  2015/02/15
# 21
# 22  74115  (918) 834-4495  2015/02/16
# 23  74115  (872) 825-8309  2014/05/12
# 24  73159  (872) 825-8309  2014/04/11
# 25
# 26  74133  (918) 252-0333  2015/02/14
# 27
# 28  73601  (580) 323-5900  2015/02/11
# 29
# 30  73120  (405) 752-5283  2014/07/27
# 31
# 32  73662  (580) 928-2700  2014/09/08
# 33
# 34  74055  (918) 272-9325  2015/02/10
# 35
# 36  74133  (918) 307-9151  2014/12/22
# 37
# 38  73103               -  2014/08/01
# 39  74135  (918) 828-0740  2015/03/11
# 40
# 41  74804               -  2014/08/20
# 42
# 43  73069               -  2014/07/21
# 44
# 45  73105  (405) 528-7427  2015/02/23

# %%
camelot.plot(tables[0], kind='contour').show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [raw]
# ['72,95,209,327,442,529,566,606,683']

# %%
camelot.plot(tables[0], kind='grid').show()
# Out:
# <img src="data:image/png;base64,..." width="432">
