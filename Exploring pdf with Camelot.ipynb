# %%
import camelot
# %matplotlib notebook

# %% [markdown]
# # Exploring page 1

# %%
tables = camelot.read_pdf('document.pdf', pages='1', flavor='stream')

# %%
tables.n
# Out:
# 1

# %%
tables[0].df
# Out:
#                                                     0          1  \
# 0   RESUMEN COTIZACIONES Y DEPOSITOS DEL FONDO DE ...
# 1                                  FONDO DE PENSIONES
# 2
# 3                 Renta Imponible  Fondo de Pensiones  2.463.129
# 4
# 5                              Cotización Obligatoria    281.782
# 6              Seguro Invalidez y Sobrevivencia (SIS)     31.036
# 7                        Cotización Voluntaria (APVI)          0
# 8                                  Depósito Convenido          0
# 9                        Depósito en Cuenta de Ahorro          0
# 10               Aportes de Indemnización Sustitutiva          0
# 11                    Cotización por Trabajos Pesados          0
# 12     AHORRO PREVISIONAL VOLUNTARIO COLECTIVO (APVC)
# 13
# 14                            APV Colectivo Empleador          0
# 15
# 16                           APV Colectivo Trabajador          0
# 17
# 18                                AFILIADO VOLUNTARIO
# 19
# ...

# %% [markdown]
# # LATTICE

# %%
tables = camelot.read_pdf('document.pdf', pages='2', flavor='lattice')

# %%
tables.n
# Out:
# 2

# %%
tables[1].df
# Out:
#                                                0   \
# 0                   Identificación del Trabajador
# 1                                             RUT
# 2                                    13.278.815-4
# 3     6.113.761-0 GONZALEZ NUNEZ HECTOR GUILLERMO
# 4       16.747.157-9 HUERTA MELLA MARLEN VIRGINIA
# 5  8.868.203-3 MUNOZ SANDOVAL PATRICIA DEL CARMEN
# 6                                    16.750.572-4
# 7                               TOTALES GENERALES
#
#                                    1                        2   \
# 0                                           Fondo de Pensiones
# 1  Apellido Paterno, Materno, Nombres  Remuneración\nImponible
# 2    BARRA ASTUDILLO MAURICIO ARMANDO                  574.346
# 3                                                      284.289
# 4                                                      237.504
# 5                                                      756.849
# 6          PELLEGRINI RIQUELME SILVIA                  610.141
# ...

# %% [raw]
# ['59, 223, 272, 313, 354, 395, 437, 478, 519, 568, 609, 650, 691, 732']

# %% [markdown]
# # STREAM

# %%
tables2 = camelot.read_pdf('document.pdf', pages='2', flavor='stream')

# %%
tables2.n
# Out:
# 1

# %%
tables2[0].df
# Out:
#                                                    0             1   \
# 0                       Identificación del Trabajador
# 1             RUT\nApellido Paterno, Materno, Nombres  Remuneración
# 2                                                         Imponible
# 3
# 4      13.278.815-4\nBARRA ASTUDILLO MAURICIO ARMANDO       574.346
# 5         6.113.761-0 GONZALEZ NUNEZ HECTOR GUILLERMO       284.289
# 6           16.747.157-9 HUERTA MELLA MARLEN VIRGINIA       237.504
# 7      8.868.203-3 MUNOZ SANDOVAL PATRICIA DEL CARMEN       756.849
# 8            16.750.572-4\nPELLEGRINI RIQUELME SILVIA       610.141
# 9                                   TOTALES GENERALES     2.463.129
# 10  Descripción de Códigos de Movimiento de Person...
#
#              2       3                   4            5          6  7   \
# 0                        Fondo de Pensiones
# 1    Cotización     SIS          Cotización  N° Contrato   Deposito
# ...

# %%
tables2[0].df.iloc[5, 1]
# Out:
# '284.289'
