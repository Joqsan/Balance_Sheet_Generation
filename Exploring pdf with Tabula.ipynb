# %%
import tabula

# %%
tabula.convert_into('document.pdf', 'test.csv', output_format="csv", stream=True, pages=2)

# %%
import pandas as pd

# %%
pd.read_csv('test.csv')
# Out:
#      Unnamed: 0       Identificación del Trabajador    Unnamed: 2  \
# 0           RUT  Apellido Paterno, Materno, Nombres  Remuneración
# 1           NaN                                 NaN     Imponible
# 2           NaN                                 NaN           NaN
# 3  13.278.815-4    BARRA ASTUDILLO MAURICIO ARMANDO       574.346
# 4   6.113.761-0     GONZALEZ NUNEZ HECTOR GUILLERMO       284.289
# 5  16.747.157-9        HUERTA MELLA MARLEN VIRGINIA       237.504
# 6   8.868.203-3  MUNOZ SANDOVAL PATRICIA DEL CARMEN       756.849
# 7  16.750.572-4          PELLEGRINI RIQUELME SILVIA       610.141
# 8           NaN                   TOTALES GENERALES     2.463.129
#
#     Unnamed: 3 Unnamed: 4 Fondo de Pensiones   Unnamed: 6 Unnamed: 7  \
# 0   Cotización        SIS         Cotización  N° Contrato   Deposito
# 1  Obligatoria        NaN         Voluntaria         APVI  Convenido
# 2          NaN        NaN             (APVI)          NaN        NaN
# ...

# %% [markdown]
# # LATTICE

# %%
dfs = tabula.read_pdf("document.pdf", pages='2', lattice=True)

# %%
len(dfs)
# Out:
# 4

# %%
dfs[3]
# Out:
#   Identificación del Trabajador                  Fondo de Pensiones  \
# 0                           RUT  Apellido Paterno, Materno, Nombres
# 1                  13.278.815-4    BARRA ASTUDILLO MAURICIO ARMANDO
# 2                   6.113.761-0     GONZALEZ NUNEZ HECTOR GUILLERMO
# 3                  16.747.157-9        HUERTA MELLA MARLEN VIRGINIA
# 4                   8.868.203-3  MUNOZ SANDOVAL PATRICIA DEL CARMEN
# 5                  16.750.572-4          PELLEGRINI RIQUELME SILVIA
# 6             TOTALES GENERALES                           2.463.129
#
#            Seguro Cesantía   Movimiento de Personal Unnamed: 0  \
# 0  Remuneración\rImponible  Cotización\rObligatoria        SIS
# 1                  574.346                   65.705      7.237
# 2                  284.289                   32.523      3.582
# 3                  237.504                   27.170      2.993
# 4                  756.849                   86.584      9.536
# ...

# %% [markdown]
# # STREAM

# %%
dfs2 = tabula.read_pdf("document.pdf", pages='2', stream=True)

# %%
len(dfs2)
# Out:
# 1

# %%
dfs2[0]
# Out:
#      Unnamed: 0       Identificación del Trabajador    Unnamed: 1  \
# 0           RUT  Apellido Paterno, Materno, Nombres  Remuneración
# 1           NaN                                 NaN     Imponible
# 2           NaN                                 NaN           NaN
# 3  13.278.815-4    BARRA ASTUDILLO MAURICIO ARMANDO       574.346
# 4   6.113.761-0     GONZALEZ NUNEZ HECTOR GUILLERMO       284.289
# 5  16.747.157-9        HUERTA MELLA MARLEN VIRGINIA       237.504
# 6   8.868.203-3  MUNOZ SANDOVAL PATRICIA DEL CARMEN       756.849
# 7  16.750.572-4          PELLEGRINI RIQUELME SILVIA       610.141
# 8           NaN                   TOTALES GENERALES     2.463.129
#
#     Unnamed: 2 Unnamed: 3 Fondo de Pensiones   Unnamed: 4 Unnamed: 5  \
# 0   Cotización        SIS         Cotización  N° Contrato   Deposito
# 1  Obligatoria        NaN         Voluntaria         APVI  Convenido
# 2          NaN        NaN             (APVI)          NaN        NaN
# ...
